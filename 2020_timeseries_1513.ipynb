# %% [markdown]
# <a href="https://colab.research.google.com/github/sungueve/Yvonne-/blob/main/2020_timeseries_1513.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#installing darts -  a library for time series
# !pip install darts --quiet


import darts
print(f"Darts version: {darts.__version__}")
# Out:
# Darts version: 0.27.2

# %%
#using darts
from darts import TimeSeries

# %%
import pandas as pd

df = pd.read_csv("/content/month_year_1513.csv", header=1, names=['year_month', 'total_paid'])
print(df.shape)
df.head()
# Out:
# (55, 2)
#   year_month  total_paid
# 0    2016-05    25239.59
# 1    2016-06    25646.22
# 2    2016-07    20545.25
# 3    2016-08    18381.85
# 4    2016-09    18580.50

# %%
df.isnull
# Out:
# <bound method DataFrame.isnull of    year_month  total_paid
# 0     2016-05    25239.59
# 1     2016-06    25646.22
# 2     2016-07    20545.25
# 3     2016-08    18381.85
# 4     2016-09    18580.50
# 5     2016-10    29634.94
# 6     2016-11    27264.99
# 7     2016-12    28721.61
# 8     2017-01    28627.72
# 9     2017-02    26792.00
# 10    2017-03    29609.79
# 11    2017-04    24464.91
# 12    2017-05    24551.90
# 13    2017-06    19273.20
# 14    2017-07    22225.75
# 15    2017-08    21298.35
# 16    2017-09    24709.96
# 17    2017-10    24993.38
# 18    2017-11    24840.28
# 19    2017-12    25591.35
# 20    2018-01    22962.33
# 21    2018-02    23198.62
# 22    2018-03    26092.06
# 23    2018-04    19518.04
# 24    2018-05    16143.07
# 25    2018-06    16589.43
# 26    2018-07    13938.72
# 27    2018-08    12725.24
# 28    2018-09    16279.13
# 29    2018-10    17954.84
# 30    2018-11    18862.26
# 31    2018-12    23088.79
# 32    2019-01    26982.24
# 33    2019-02    20130.35
# 34    2019-03    25064.12
# 35    2019-04    21659.36
# 36    2019-05    17593.76
# 37    2019-06    14185.28
# 38    2019-07    14415.41
# 39    2019-08    14063.58
# 40    2019-09    19260.67
# 41    2019-10    25867.95
# 42    2019-11    22415.25
# 43    2019-12    19421.61
# 44    2020-01    23690.38
# 45    2020-02    21364.83
# 46    2020-03     6467.76
# 47    2020-05     2164.86
# 48    2020-04    19837.82
# 49    2020-06     8577.85
# 50    2020-07    10702.03
# 51    2020-08    10146.06
# 52    2020-09    13251.90
# 53    2020-10    12613.91
# 54    2020-11     2236.03>

# %%
df.tail()
# Out:
#    year_month  total_paid
# 50    2020-07    10702.03
# 51    2020-08    10146.06
# 52    2020-09    13251.90
# 53    2020-10    12613.91
# 54    2020-11     2236.03

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year_month  55 non-null     object
#  1   total_paid  55 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 1008.0+ bytes

# %%
# Convert 'month_year' column to datetime format
df['year_month'] = pd.to_datetime(df['year_month'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year_month  55 non-null     datetime64[ns]
#  1   total_paid  55 non-null     float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 1008.0 bytes

# %%
#to create a TimeSeries object, you need to specify the dataframe that you're using,
#and which is the temporal column(months) and which is the column to predict (total_value_paid)
# plot that shows how revenue varies across time

from darts import TimeSeries
series = TimeSeries.from_dataframe(df, 'year_month', 'total_paid')
series.plot()
# Out:
# <Axes: xlabel='year_month'>

# %%
#missing values
#it's important to fill missing values in the column whose values you're trying to predict (in your case the revenue column)
from darts.utils.missing_values import fill_missing_values
series = fill_missing_values(series)

# %%
series.plot()
# Out:
# <Axes: xlabel='year_month'>

# %%
#if you observe an exponential trend, do this
import numpy as np
logged = (series).map(lambda x: np.log(x))

# %%
# Set 'month_year' column as the index
df = df.set_index('year_month')

# Plot the time series
df.plot(y='total_paid', xlabel='year_month', ylabel='total_paid')
# Out:
# <Axes: xlabel='year_month', ylabel='total_paid'>

# %%
#scale the data
from darts.dataprocessing.transformers.scaler import Scaler
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
ts_transformer = Scaler(scaler)
scaled_ts = ts_transformer.fit_transform(logged)

# %%
#train test split
train, test = (series).split_before(0.8)
test.plot(label="validation")
# Out:
# <Axes: xlabel='year_month'>

# %%
#1. model option: ExponentialSmoothing
#it assigns larger weights to more recent observations while assigning exponentially
#decreasing weights as the observations get increasingly distant.

# %%
from darts.models import ExponentialSmoothing

# initialize and fit an Exponential Smoothing model
model = ExponentialSmoothing()
model.fit(train)
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# ExponentialSmoothing(trend=ModelMode.ADDITIVE, damped=False, seasonal=SeasonalityMode.ADDITIVE, seasonal_periods=None, random_state=0, kwargs=None)

# %%
# generate predictions (for the test set)
exp_forecast = model.predict(len(test))

# %%
model = ExponentialSmoothing(seasonal=SeasonalityMode.NONE)
model.fit(train)

# %%
#plot the training data, the test data and your predictions
train.plot(label="training")
test.plot(label="test data (true data)")
exp_forecast.plot(label = "predictions")
# Out:
# <Axes: xlabel='year_month'>

# %%
#evaluate how accurate your generated predictions are (compared to the true data in Test set)
from darts.metrics import mape
accuracy = mape(test, exp_forecast)
print(f"Mean Absolute Percentage Error: {accuracy}")
# Out:
# Mean Absolute Percentage Error: 191.34450007299571

# %%
#2. multiple models
from darts.models import AutoARIMA, Prophet, TBATS

# %%
#generate predictions using each of the additional models - AutoArima, Prophet and TBATS
#calculate the MAPE score for each of them
#interpret these MAPE scores by comparing them with the MAPE score that the Exponential Smoothing model gave you
results_dict = {}
for model in [AutoARIMA, Prophet, TBATS]:
    temp = model()
    temp.fit(train)
    preds = temp.predict(len(test))
    accuracy = mape(test, preds)
    results_dict[f"{model}"] = accuracy
results_dict
# Out:
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpokp_5tji/h9tpn47k.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpokp_5tji/3_jdykn8.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=19842', 'data', 'file=/tmp/tmpokp_5tji/h9tpn47k.json', 'init=/tmp/tmpokp_5tji/3_jdykn8.json', 'output', 'file=/tmp/tmpokp_5tji/prophet_modeluesdqqr0/prophet_model-20240213102257.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:22:57 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:22:57 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# {"<class 'darts.models.forecasting.auto_arima.AutoARIMA'>": 216.77623396808215,
#  "<class 'darts.models.forecasting.prophet_model.Prophet'>": 150.176689763082,
#  "<class 'darts.models.forecasting.tbats_model.TBATS'>": 203.4218769986889}

# %%
#train the model and generate predictions
temp = TBATS()
temp.fit(train)
TBATS_preds = temp.predict(len(test))


train.plot(label="training")
test.plot(label="test data (true data)")
TBATS_preds.plot(label = "predictions")
# Out:
# <Axes: xlabel='year_month'>

# %%
# !pip install prophet
# Out:
# Requirement already satisfied: prophet in /usr/local/lib/python3.10/dist-packages (1.1.5)
# Requirement already satisfied: cmdstanpy>=1.0.4 in /usr/local/lib/python3.10/dist-packages (from prophet) (1.2.1)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.10/dist-packages (from prophet) (1.23.5)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from prophet) (3.7.1)
# Requirement already satisfied: pandas>=1.0.4 in /usr/local/lib/python3.10/dist-packages (from prophet) (1.5.3)
# Requirement already satisfied: holidays>=0.25 in /usr/local/lib/python3.10/dist-packages (from prophet) (0.42)
# Requirement already satisfied: tqdm>=4.36.1 in /usr/local/lib/python3.10/dist-packages (from prophet) (4.66.1)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from prophet) (6.1.1)
# Requirement already satisfied: stanio~=0.3.0 in /usr/local/lib/python3.10/dist-packages (from cmdstanpy>=1.0.4->prophet) (0.3.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from holidays>=0.25->prophet) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (4.48.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (3.1.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.4->prophet) (2023.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil->holidays>=0.25->prophet) (1.16.0)

# %%
from prophet import Prophet

# %%
import pandas as pd

df = pd.read_csv("/content/month_year_1513.csv")

# fitting the Prophet model
m = Prophet()
m.fit(df.rename(columns={"year_month": "ds", "total_paid": "y"}))
# Out:
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiajw5yto/cnzdpdtz.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiajw5yto/cdjv09wu.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=77952', 'data', 'file=/tmp/tmpiajw5yto/cnzdpdtz.json', 'init=/tmp/tmpiajw5yto/cdjv09wu.json', 'output', 'file=/tmp/tmpiajw5yto/prophet_modelwej4w9ub/prophet_model-20240213135656.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 13:56:56 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 13:56:57 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
future = m.make_future_dataframe(periods=12, freq="m")
future.tail()
# Out:
#            ds
# 63 2021-06-30
# 64 2021-07-31
# 65 2021-08-31
# 66 2021-09-30
# 67 2021-10-31

# %%
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#            ds          yhat    yhat_lower    yhat_upper
# 63 2021-06-30   4926.581984    463.096061   9373.235986
# 64 2021-07-31   5106.542713    556.604744   9783.440976
# 65 2021-08-31  11828.614246   7410.121885  16310.195653
# 66 2021-09-30  15289.154445  10761.567152  19873.420812
# 67 2021-10-31  16731.443970  12553.670613  21326.670714

# %%
fig1 = m.plot(forecast)

# %%
forecast.head()
# Out:
#           ds         trend    yhat_lower    yhat_upper   trend_lower  \
# 0 2016-04-01  26018.440097  22939.754938  31895.514564  26018.440097
# 1 2016-05-01  25774.964561  17567.900484  26443.428899  25774.964561
# 2 2016-06-01  25523.373173  19941.748559  28517.103919  25523.373173
# 3 2016-07-01  25279.897637  18735.060045  27449.639129  25279.897637
# 4 2016-08-01  25028.306250  17320.707069  26129.504272  25028.306250
#
#     trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 0  26018.440097     1446.942602           1446.942602           1446.942602
# 1  25774.964561    -3609.251576          -3609.251576          -3609.251576
# 2  25523.373173    -1579.215690          -1579.215690          -1579.215690
# 3  25279.897637    -2157.716466          -2157.716466          -2157.716466
# 4  25028.306250    -3293.338394          -3293.338394          -3293.338394
#
#         yearly  yearly_lower  yearly_upper  multiplicative_terms  \
# 0  1446.942602   1446.942602   1446.942602                   0.0
# 1 -3609.251576  -3609.251576  -3609.251576                   0.0
# 2 -1579.215690  -1579.215690  -1579.215690                   0.0
# 3 -2157.716466  -2157.716466  -2157.716466                   0.0
# 4 -3293.338394  -3293.338394  -3293.338394                   0.0
#
#    multiplicative_terms_lower  multiplicative_terms_upper          yhat
# 0                         0.0                         0.0  27465.382699
# 1                         0.0                         0.0  22165.712985
# 2                         0.0                         0.0  23944.157483
# 3                         0.0                         0.0  23122.181171
# 4                         0.0                         0.0  21734.967856

# %%
m.plot_components(forecast)

# %%
from prophet.plot import plot_plotly, plot_components_plotly

plot_plotly(m, forecast)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="3612c691-bb67-4055-8a59-3b85417ba6d9" class="plotly-graph-div" style="height:600px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("